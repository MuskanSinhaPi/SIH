# %%
import pandas as pd
import numpy as np

# %%
#nudge related to air and water
nudge="use bucket instead of hose pipe for was"
print(indicator_generator(nudge))
# Out:
# ```
# {
#   "Category": "Single-Use Plastic Reduced",
#   "Top 5 Relevant Indicators": [
#     "Plastic waste generation per capita",
#     "Reduction in plastic packaging",
#     "Benzene",
#     "PM10",
#     "PM2.5"
#   ],
#   "Correlation Statements": {
#     "Plastic waste generation per capita": "A reduction in plastic waste generation per capita is correlated with a decrease in the use of single-use plastic bags.",
#     "Reduction in plastic packaging": "A decrease in plastic packaging is correlated with a reduction in the use of single-use plastic bags.",
#     "Benzene": "A reduction in benzene emissions is correlated with a decrease in the use of single-use plastic bags.",
#     "PM10": "A reduction in PM10 emissions is correlated with a decrease in the use of single-use plastic bags.",
#     "PM2.5": "A reduction in PM2.5 emissions is correlated with a decrease in the use of single-use plastic bags."
#   }
# }
# ```

# %%
arr = indicator_generator(nudge)

# %%
arr
# Out:
# 'Water conserved'

# %%
response.text

# %%
# View the response candidates
response.candidates

# %%
# If API failed to return a result, use prompt_feedback to see if it was blocked due to safety concerns regarding the prompt.
response.prompt_feedback

# %% [markdown]
# ### Generate text from image and text prompts using `gemini-pro-vision`

# %%
# !curl -o image.jpg https://t0.gstatic.com/licensed-image?q=tbn:ANd9GcQ_Kevbk21QBRy-PgB4kQpS79brbmmEG7m3VOTShAn4PecDU5H5UxrJxE3Dw1JiaG17V88QIol19-3TM2wCHw

# %%
import PIL.Image

img = PIL.Image.open('/kaggle/input/imagetodiagram/WhatsApp Image 2023-12-16 at 02.23.02_e4d80174.jpg')
img

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content(img)

to_markdown(response.text)

# %%
response = model.generate_content(["Write a short, engaging blog post based on this picture. It should include a description of the meal in the photo and talk about my journey meal prepping.", img])
to_markdown(response.text)
